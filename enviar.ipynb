# %%
import requests
resp = requests.get("http://api.senapp.software/")
print(resp.text)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     <a href='file:///c%3A/Users/luisf/AppData/Roaming/Python/Python310/site-packages/urllib3/connection.py?line=172'>173</a> try:
# --> <a href='file:///c%3A/Users/luisf/AppData/Roaming/Python/Python310/site-packages/urllib3/connection.py?line=173'>174</a>     conn = connection.create_connection(
#     <a href='file:///c%3A/Users/luisf/AppData/Roaming/Python/Python310/site-packages/urllib3/connection.py?line=174'>175</a>         (self._dns_host, self.port), self.timeout, **extra_kw
#     <a href='file:///c%3A/Users/luisf/AppData/Roaming/Python/Python310/site-packages/urllib3/connection.py?line=175'>176</a>     )
# ...
